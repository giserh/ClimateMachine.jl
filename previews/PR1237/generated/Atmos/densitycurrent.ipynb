# %% [markdown]
# # Density Current
#
# In this example, we demonstrate the usage of the `ClimateMachine`
# AtmosModel machinery to solve the fluid
# dynamics of the clasical density current test by Straka 1993.
# We solve a flow in a
# `FlatOrientation` (Box) configuration - this is
# representative of a large-eddy simulation. Several versions of the problem
# setup may be found in literature, but the general idea is to examine the
# vertical ascent of a thermal _bubble_ (we can interpret these as simple
# representation of convective updrafts).
#
# ## Description of experiment
# The setup described below is such that the simulation reaches completion
# (timeend = 900 s) in approximately 4 minutes of wall-clock time on 1 GPU
#
# 1) Dry Density Current (circular potential temperature perturbation)
# 2) Boundaries
#    - `Impenetrable(FreeSlip())` - no momentum flux, no mass flux through
#      walls.
#    - `Impermeable()` - non-porous walls, i.e. no diffusive fluxes through
#       walls.
# 3) Domain - 25600m (horizontal) x 10000m (horizontal) x 6400m (vertical)
# 4) Resolution - 100m effective resolution
# 5) Total simulation time - 900s
# 6) Mesh Aspect Ratio (Effective resolution) 1:1
# 7) Overrides defaults for
#    - CPU Initialisation
#    - Time integrator
#    - Sources
#    - Smagorinsky Coefficient _C_smag
# 8) Default settings can be found in `src/Driver/<files>.jl`

# %% [markdown]
# ## Boilerplate (Using Modules)
#
# #### Skip Section
#
# Before setting up our experiment, we recognize that we need to import some
# pre-defined functions from other packages. Julia allows us to use existing
# modules (variable workspaces), or write our own to do so.  Complete
# documentation for the Julia module system can be found
# [here](https://docs.julialang.org/en/v1/manual/modules/#).

# %% [markdown]
# We need to use the `ClimateMachine` module! This imports all functions
# specific to atmospheric and ocean flow modelling.  While we do not cover the
# ins-and-outs of the contents of each of these we provide brief descriptions
# of the utility of each of the loaded packages.

# %%
using ClimateMachine
ClimateMachine.cli()

using ClimateMachine.Atmos

# %% [markdown]
# - Required so that we inherit the appropriate model types for the large-eddy
#   simulation (LES) and global-circulation-model (GCM) configurations.

# %%
using ClimateMachine.ConfigTypes

# %% [markdown]
# - Required so that we may define diagnostics configurations, e.g. choice of
#   file-writer, choice of output variable sets, output-frequency and directory,

# %%
using ClimateMachine.Diagnostics

# %% [markdown]
# - Required so that we may define (or utilise existing functions) functions
#   that are `called-back` or executed at frequencies of either timesteps,
#   simulation-time, or wall-clock time.

# %%
using ClimateMachine.GenericCallbacks

# %% [markdown]
# - Required so we load the appropriate functions for the time-integration
#   component. Contains ODESolver methods.

# %%
using ClimateMachine.ODESolvers

# %% [markdown]
# - Required for utility of spatial filtering functions (e.g. positivity
#   preservation)

# %%
using ClimateMachine.Mesh.Filters

# %% [markdown]
# - Required so functions for computation of temperature profiles.

# %%
using ClimateMachine.TemperatureProfiles

# %% [markdown]
# - Required so functions for computation of moist thermodynamic quantities is
#   enabled.

# %%
using ClimateMachine.Thermodynamics

# %% [markdown]
# - Required so we may access our variable arrays by a sensible naming
#   convention rather than by numerical array indices.

# %%
using ClimateMachine.VariableTemplates

# %% [markdown]
# - Required so we may access planet parameters
#   ([CLIMAParameters](https://CliMA.github.io/CLIMAParameters.jl/latest/)
#   specific to this problem include the gas constant, specific heats,
#   mean-sea-level pressure, gravity and the Smagorinsky coefficient)

# %% [markdown]
# In ClimateMachine we use `StaticArrays` for our variable arrays.

# %%
using StaticArrays

# %% [markdown]
# We also use the `Test` package to help with unit tests and continuous
# integration systems to design sensible tests for our experiment to ensure new
# / modified blocks of code don't damage the fidelity of the physics. The test
# defined within this experiment is not a unit test for a specific
# subcomponent, but ensures time-integration of the defined problem conditions
# within a reasonable tolerance. Immediately useful macros and functions from
# this include `@test` and `@testset` which will allow us to define the testing
# parameter sets.

# %%
using Test

using CLIMAParameters
using CLIMAParameters.Atmos.SubgridScale: C_smag
using CLIMAParameters.Planet: R_d, cp_d, cv_d, MSLP, grav
struct EarthParameterSet <: AbstractEarthParameterSet end
const param_set = EarthParameterSet()
# Out:
# Main.##378.EarthParameterSet()

# %% [markdown]
# ## Initial Conditions
# This example of a Density Current can be classified as an initial value
# problem. We must (at the very least) assign values for the initial variables
# in a sensible manner. This example demonstrates the use of functions defined
# in the `MoistThermodynamics` package to
# generate the appropriate initial state for our problem.

# %%
function init_densitycurrent!(bl, state, aux, (x, y, z), t)
    # Problem float-type
    FT = eltype(state)

    # Unpack constant parameters
    R_gas::FT = R_d(bl.param_set)
    c_p::FT = cp_d(bl.param_set)
    c_v::FT = cv_d(bl.param_set)
    p0::FT = MSLP(bl.param_set)
    _grav::FT = grav(bl.param_set)
    γ::FT = c_p / c_v

    # Define bubble center and background potential temperature
    xc::FT = 0
    yc::FT = 0
    zc::FT = 3000
    rx::FT = 4000
    rz::FT = 2000
    r = sqrt(((x - xc)^2) / rx^2 + ((z - zc)^2) / rz^2)

    # TODO: clean this up, or add convenience function:
    # This is configured in the reference hydrostatic state
    θ_ref::FT = bl.ref_state.virtual_temperature_profile.T_surface
    Δθ::FT = 0
    θamplitude::FT = -15.0

    # Compute temperature difference over bubble region
    if r <= 1
        Δθ = 0.5 * θamplitude * (1 + cospi(r))
    end

    # Compute perturbed thermodynamic state:
    θ = θ_ref + Δθ                                      ## potential temperature
    π_exner = FT(1) - _grav / (c_p * θ) * z             ## exner pressure
    ρ = p0 / (R_gas * θ) * (π_exner)^(c_v / R_gas)      ## density
    T = θ * π_exner
    e_int = internal_energy(bl.param_set, T)
    ts = PhaseDry(bl.param_set, e_int, ρ)
    ρu = SVector(FT(0), FT(0), FT(0))                   ## momentum
    # State (prognostic) variable assignment
    e_kin = FT(0)                                       ## kinetic energy
    e_pot = gravitational_potential(bl.orientation, aux)## potential energy
    ρe_tot = ρ * total_energy(e_kin, e_pot, ts)         ## total energy

    # Assign State Variables
    state.ρ = ρ
    state.ρu = ρu
    state.ρe = ρe_tot
end
# Out:
# init_densitycurrent! (generic function with 1 method)

# %% [markdown]
# ## Model Configuration
# We define a configuration function to assist in prescribing the physical
# model. The purpose of this is to populate the
# `ClimateMachine.AtmosLESConfiguration` with arguments
# appropriate to the problem being considered.

# %%
function config_densitycurrent(FT, N, resolution, xmax, ymax, zmax)

    # Choose an Explicit Single-rate Solver LSRK144 from the existing [ODESolvers](@ref
    # ODESolvers-docs) options Apply the outer constructor to define the
    ode_solver = ClimateMachine.ExplicitSolverType(
        solver_method = LSRK144NiegemannDiehlBusch,
    )

    # The model coefficient for the turbulence closure is defined via the
    # [CLIMAParameters
    # package](https://CliMA.github.io/CLIMAParameters.jl/latest/) A reference
    # state for the linearisation step is also defined.
    T_surface = FT(300)
    T_min_ref = FT(0)
    T_profile = DryAdiabaticProfile{FT}(param_set, T_surface, T_min_ref)
    ref_state = HydrostaticState(T_profile)

    # The fun part! Here we assemble the `AtmosModel`.
    ##md # !!! note
    ##md #     Docs on model subcomponent options can be found here:
    ##md #     - [`param_set`](https://CliMA.github.io/CLIMAParameters.jl/latest/)
    ##md #     - `turbulence`
    ##md #     - `hyperdiffusion`
    ##md #     - `source`
    ##md #     - `init_state`

    _C_smag = FT(0.21)
    model = AtmosModel{FT}(
        AtmosLESConfigType,                             ## Flow in a box, requires the AtmosLESConfigType
        param_set;                                      ## Parameter set corresponding to earth parameters
        turbulence = Vreman(_C_smag),                   ## Turbulence closure model
        moisture = DryModel(),                          ## Exclude moisture variables
        source = (Gravity(),),                          ## Gravity is the only source term here
        tracers = NoTracers(),                          ## Tracer model with diffusivity coefficients
        ref_state = ref_state,                          ## Reference state
        init_state_conservative = init_densitycurrent!, ## Apply the initial condition
    )

    # Finally, we pass a `Problem Name` string, the mesh information, and the
    # model type to  the [`AtmosLESConfiguration`] object.
    config = ClimateMachine.AtmosLESConfiguration(
        "DryDensitycurrent",      ## Problem title [String]
        N,                        ## Polynomial order [Int]
        resolution,               ## (Δx, Δy, Δz) effective resolution [m]
        xmax,                     ## Domain maximum size [m]
        ymax,                     ## Domain maximum size [m]
        zmax,                     ## Domain maximum size [m]
        param_set,                ## Parameter set.
        init_densitycurrent!,     ## Function specifying initial condition
        solver_type = ode_solver, ## Time-integrator type
        model = model,            ## Model type
        periodicity = (false, false, false),
        boundary = ((1, 1), (1, 1), (1, 1)),   ##Set all boundaries to solid walls
    )
    return config
end


function main()
    # These are essentially arguments passed to the
    # `config_densitycurrent` function.  For type
    # consistency we explicitly define the problem floating-precision.
    FT = Float64
    # We need to specify the polynomial order for the DG discretization,
    # effective resolution, simulation end-time, the domain bounds, and the
    # courant-number for the time-integrator. Note how the time-integration
    # components `solver_config` are distinct from the spatial / model
    # components in `driver_config`. `init_on_cpu` is a helper keyword argument
    # that forces problem initialisation on CPU (thereby allowing the use of
    # random seeds, spline interpolants and other special functions at the
    # initialisation step.)
    N = 4
    Δx = FT(100)
    Δy = FT(250)
    Δv = FT(100)
    resolution = (Δx, Δy, Δv)
    xmax = FT(25600)
    ymax = FT(1000)
    zmax = FT(6400)
    t0 = FT(0)
    timeend = FT(1000)
    CFL = FT(1.5)

    # Assign configurations so they can be passed to the `invoke!` function
    driver_config = config_densitycurrent(FT, N, resolution, xmax, ymax, zmax)
    solver_config = ClimateMachine.SolverConfiguration(
        t0,
        timeend,
        driver_config,
        init_on_cpu = true,
        Courant_number = CFL,
    )

    # Invoke solver (calls `solve!` function for time-integrator), pass the driver, solver and diagnostic config
    # information.
    result =
        ClimateMachine.invoke!(solver_config; check_euclidean_distance = true)

    # Check that the solution norm is reasonable.
    @test isapprox(result, FT(1); atol = 1.5e-2)
end
# Out:
# main (generic function with 1 method)

# %% [markdown]
# The experiment definition is now complete. Time to run it.
# julia --project=$CLIMA_HOME tutorials/Atmos/densitycurrent.jl --vtk 1smins
# to run with VTK output enabled at intervals of 1 simulation minute.

# %%
# References

# %% [markdown]
# [1] J. Straka, R. Wilhelmson, L. Wicker, J. Anderson, K. Droegemeier,
# Numerical solution of a nonlinear density current: a benchmark solution and comparisons
# Int. J. Numer. Methods Fluids 17 (1993) 1–22,  https://doi.org/10.1002/fld.1650170103
# [2] R. Carpenter, K. Droegemeier, P. Woodward, C. Hane,
# Application of the piecewise parabolic method (PPM) to meteorological modeling,
# Mon. Weather Rev. 118 (1990) 586–612, https://doi.org/10.1175/1520-0493(1990)118<0586:AOTPPM>2.0.CO;2

# %%
main()
# Out:
# ┌ Info: Model composition
# │     param_set = Main.##378.EarthParameterSet()
# │     orientation = ClimateMachine.Atmos.FlatOrientation()
# │     ref_state = ClimateMachine.Atmos.HydrostaticState{ClimateMachine.TemperatureProfiles.DryAdiabaticProfile{Float64},Float64}(ClimateMachine.TemperatureProfiles.DryAdiabaticProfile{Float64}(300.0, 0.0), 0.0)
# │     turbulence = ClimateMachine.Atmos.Vreman{Float64}(0.21)
# │     hyperdiffusion = ClimateMachine.Atmos.NoHyperDiffusion()
# │     moisture = ClimateMachine.Atmos.DryModel()
# │     precipitation = ClimateMachine.Atmos.NoPrecipitation()
# │     radiation = ClimateMachine.Atmos.NoRadiation()
# │     source = (ClimateMachine.Atmos.Gravity(),)
# │     tracers = ClimateMachine.Atmos.NoTracers()
# │     boundarycondition = ClimateMachine.Atmos.AtmosBC{ClimateMachine.Atmos.Impenetrable{ClimateMachine.Atmos.FreeSlip},ClimateMachine.Atmos.Insulating,ClimateMachine.Atmos.Impermeable,ClimateMachine.Atmos.ImpermeableTracer}(ClimateMachine.Atmos.Impenetrable{ClimateMachine.Atmos.FreeSlip}(ClimateMachine.Atmos.FreeSlip()), ClimateMachine.Atmos.Insulating(), ClimateMachine.Atmos.Impermeable(), ClimateMachine.Atmos.ImpermeableTracer())
# │     init_state_conservative = init_densitycurrent!
# │     data_config = nothing
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:99
# ┌ Info: Establishing Atmos LES configuration for DryDensitycurrent
# │     precision        = Float64
# │     polynomial order = 4
# │     domain           = 25600.00 m x1000.00 m x6400.00 m
# │     resolution       = 100x250x100
# │     MPI ranks        = 1
# │     min(Δ_horz)      = 69.07 m
# │     min(Δ_vert)      = 69.07 m
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/driver_configs.jl:155
# ┌ Info: Initializing DryDensitycurrent
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/solver_configs.jl:134
# ┌ Info: Starting DryDensitycurrent
# │     dt              = 2.98329e-01
# │     timeend         =  1000.00
# │     number of steps = 3352
# │     norm(Q)         = 9.9116594163651257e+09
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:570
# ┌ Info: Update
# │     simtime =     5.07 /  1000.00
# │     runtime = 00:01:00
# │     norm(Q) = 9.9097401244801025e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    17.30 /  1000.00
# │     runtime = 00:02:01
# │     norm(Q) = 9.9098939667581177e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    29.53 /  1000.00
# │     runtime = 00:03:01
# │     norm(Q) = 9.9094506245345955e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    42.06 /  1000.00
# │     runtime = 00:04:02
# │     norm(Q) = 9.9094868773902283e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    54.30 /  1000.00
# │     runtime = 00:05:02
# │     norm(Q) = 9.9097697054284134e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    66.53 /  1000.00
# │     runtime = 00:06:04
# │     norm(Q) = 9.9096790716767769e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    78.76 /  1000.00
# │     runtime = 00:07:04
# │     norm(Q) = 9.9104329935872078e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =    90.99 /  1000.00
# │     runtime = 00:08:05
# │     norm(Q) = 9.9103136835021687e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   103.22 /  1000.00
# │     runtime = 00:09:06
# │     norm(Q) = 9.9102515920001411e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   115.45 /  1000.00
# │     runtime = 00:10:08
# │     norm(Q) = 9.9112085710437889e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   127.39 /  1000.00
# │     runtime = 00:11:08
# │     norm(Q) = 9.9112560806794662e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   139.32 /  1000.00
# │     runtime = 00:12:08
# │     norm(Q) = 9.9112859583026905e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   151.85 /  1000.00
# │     runtime = 00:13:09
# │     norm(Q) = 9.9130610905929394e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   164.08 /  1000.00
# │     runtime = 00:14:10
# │     norm(Q) = 9.9128058522141018e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   176.31 /  1000.00
# │     runtime = 00:15:10
# │     norm(Q) = 9.9123917817079906e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   188.84 /  1000.00
# │     runtime = 00:16:10
# │     norm(Q) = 9.9139961162149582e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   201.37 /  1000.00
# │     runtime = 00:17:10
# │     norm(Q) = 9.9140134353942719e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   214.20 /  1000.00
# │     runtime = 00:18:11
# │     norm(Q) = 9.9140455020107899e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   227.03 /  1000.00
# │     runtime = 00:19:12
# │     norm(Q) = 9.9153991074095860e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   239.56 /  1000.00
# │     runtime = 00:20:13
# │     norm(Q) = 9.9157390078634338e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   252.09 /  1000.00
# │     runtime = 00:21:13
# │     norm(Q) = 9.9151967301099834e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   264.62 /  1000.00
# │     runtime = 00:22:14
# │     norm(Q) = 9.9164208769855785e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   277.15 /  1000.00
# │     runtime = 00:23:14
# │     norm(Q) = 9.9164287195961113e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   289.68 /  1000.00
# │     runtime = 00:24:15
# │     norm(Q) = 9.9156555347188168e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   302.21 /  1000.00
# │     runtime = 00:25:15
# │     norm(Q) = 9.9176585575347538e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   314.74 /  1000.00
# │     runtime = 00:26:15
# │     norm(Q) = 9.9170317248571644e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   327.57 /  1000.00
# │     runtime = 00:27:17
# │     norm(Q) = 9.9158508616982727e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   340.10 /  1000.00
# │     runtime = 00:28:17
# │     norm(Q) = 9.9171197445307980e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   352.63 /  1000.00
# │     runtime = 00:29:18
# │     norm(Q) = 9.9162792600109901e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   365.16 /  1000.00
# │     runtime = 00:30:18
# │     norm(Q) = 9.9154725407727375e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   377.98 /  1000.00
# │     runtime = 00:31:20
# │     norm(Q) = 9.9166236905454254e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   390.81 /  1000.00
# │     runtime = 00:32:21
# │     norm(Q) = 9.9158045649925289e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   403.64 /  1000.00
# │     runtime = 00:33:22
# │     norm(Q) = 9.9155212836267452e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   416.17 /  1000.00
# │     runtime = 00:34:22
# │     norm(Q) = 9.9160044694864082e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   429.00 /  1000.00
# │     runtime = 00:35:23
# │     norm(Q) = 9.9155134601414433e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   441.53 /  1000.00
# │     runtime = 00:36:24
# │     norm(Q) = 9.9154893875539837e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   454.06 /  1000.00
# │     runtime = 00:37:25
# │     norm(Q) = 9.9162056120761261e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   466.59 /  1000.00
# │     runtime = 00:38:26
# │     norm(Q) = 9.9153691063152218e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   479.12 /  1000.00
# │     runtime = 00:39:26
# │     norm(Q) = 9.9161621591167679e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   491.95 /  1000.00
# │     runtime = 00:40:27
# │     norm(Q) = 9.9156562803775349e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   504.47 /  1000.00
# │     runtime = 00:41:27
# │     norm(Q) = 9.9152973916669998e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   517.30 /  1000.00
# │     runtime = 00:42:29
# │     norm(Q) = 9.9156803679238682e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   530.13 /  1000.00
# │     runtime = 00:43:30
# │     norm(Q) = 9.9149942401301174e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   542.66 /  1000.00
# │     runtime = 00:44:30
# │     norm(Q) = 9.9152388139491711e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   555.19 /  1000.00
# │     runtime = 00:45:30
# │     norm(Q) = 9.9153853806518288e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   567.72 /  1000.00
# │     runtime = 00:46:31
# │     norm(Q) = 9.9147910831054840e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   580.25 /  1000.00
# │     runtime = 00:47:31
# │     norm(Q) = 9.9150902616900597e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   592.78 /  1000.00
# │     runtime = 00:48:32
# │     norm(Q) = 9.9152536932708416e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   605.31 /  1000.00
# │     runtime = 00:49:32
# │     norm(Q) = 9.9148147877834167e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   617.84 /  1000.00
# │     runtime = 00:50:33
# │     norm(Q) = 9.9151133389407082e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   630.37 /  1000.00
# │     runtime = 00:51:34
# │     norm(Q) = 9.9148076540960159e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   642.90 /  1000.00
# │     runtime = 00:52:35
# │     norm(Q) = 9.9147153503789825e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   655.13 /  1000.00
# │     runtime = 00:53:35
# │     norm(Q) = 9.9151481602774677e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   667.66 /  1000.00
# │     runtime = 00:54:36
# │     norm(Q) = 9.9146097593991051e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   680.19 /  1000.00
# │     runtime = 00:55:37
# │     norm(Q) = 9.9140546606979713e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   692.72 /  1000.00
# │     runtime = 00:56:37
# │     norm(Q) = 9.9149062632611027e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   705.25 /  1000.00
# │     runtime = 00:57:38
# │     norm(Q) = 9.9145657356188412e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   718.08 /  1000.00
# │     runtime = 00:58:39
# │     norm(Q) = 9.9139055240304718e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   730.61 /  1000.00
# │     runtime = 00:59:39
# │     norm(Q) = 9.9147448416529522e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   743.14 /  1000.00
# │     runtime = 01:00:40
# │     norm(Q) = 9.9142779822985630e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   755.67 /  1000.00
# │     runtime = 01:01:41
# │     norm(Q) = 9.9143627233113060e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   768.20 /  1000.00
# │     runtime = 01:02:41
# │     norm(Q) = 9.9144330780620804e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   780.73 /  1000.00
# │     runtime = 01:03:43
# │     norm(Q) = 9.9142052752894020e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   792.96 /  1000.00
# │     runtime = 01:04:43
# │     norm(Q) = 9.9143544679634037e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   805.19 /  1000.00
# │     runtime = 01:05:44
# │     norm(Q) = 9.9143529416412106e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   817.42 /  1000.00
# │     runtime = 01:06:45
# │     norm(Q) = 9.9145143313892937e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   829.36 /  1000.00
# │     runtime = 01:07:45
# │     norm(Q) = 9.9144714145495205e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   841.59 /  1000.00
# │     runtime = 01:08:46
# │     norm(Q) = 9.9136158619492569e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   853.82 /  1000.00
# │     runtime = 01:09:48
# │     norm(Q) = 9.9147948340539799e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   865.75 /  1000.00
# │     runtime = 01:10:48
# │     norm(Q) = 9.9144665286051655e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   877.98 /  1000.00
# │     runtime = 01:11:49
# │     norm(Q) = 9.9138084535474720e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   890.51 /  1000.00
# │     runtime = 01:12:50
# │     norm(Q) = 9.9155965957575951e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   903.04 /  1000.00
# │     runtime = 01:13:51
# │     norm(Q) = 9.9151810411727047e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   915.57 /  1000.00
# │     runtime = 01:14:52
# │     norm(Q) = 9.9148315067096443e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   927.80 /  1000.00
# │     runtime = 01:15:53
# │     norm(Q) = 9.9162917107505703e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   940.33 /  1000.00
# │     runtime = 01:16:54
# │     norm(Q) = 9.9161526865442429e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   952.86 /  1000.00
# │     runtime = 01:17:55
# │     norm(Q) = 9.9167951775614834e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   965.39 /  1000.00
# │     runtime = 01:18:55
# │     norm(Q) = 9.9189595398109684e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   977.92 /  1000.00
# │     runtime = 01:19:56
# │     norm(Q) = 9.9199134506292877e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Update
# │     simtime =   990.45 /  1000.00
# │     runtime = 01:20:57
# │     norm(Q) = 9.9216274696815109e+09
# └ @ ClimateMachine.Callbacks /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Utilities/Callbacks/Callbacks.jl:53
# ┌ Info: Finished
# │     norm(Q)            = 9.9253445810056419e+09
# │     norm(Q) / norm(Q₀) = 1.0013807137700799e+00
# │     norm(Q) - norm(Q₀) = 1.3685164640516281e+07
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:618
# ┌ Info: Euclidean distance
# │     norm(Q - Qe)            = 7.3513942199881911e+08
# │     norm(Q - Qe) / norm(Qe) = 7.4169156860356952e-02
# └ @ ClimateMachine /home/runner/work/ClimateMachine.jl/ClimateMachine.jl/src/Driver/Driver.jl:634
# Test Passed

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
